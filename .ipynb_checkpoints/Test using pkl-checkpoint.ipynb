# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle as pkl
import warnings
warnings.filterwarnings('ignore')

# %%
pipe = pkl.load(open("CPP.pkl","rb+"))

# %%
name = input("Enter Car Name")
company = input("Enter Company name")
year = int(input("Enter year"))
kms_driven = int(input("Enter kms_driven"))
fuel_type = input("Enter fuel_type ")
# Out:
# Enter Car Name Suzuki Swift Dzire VXi 1.2 BS IV
# Enter Company name Maruti
# Enter year 2017
# Enter kms_driven 35000
# Enter fuel_type  Petrol

# %%
print(name,"-",company,"-",year,"-",kms_driven,"-",fuel_type)
# Out:
# Suzuki Swift Dzire VXi 1.2 BS IV - Maruti - 2017 - 35000 - Petrol

# %%
input = pd.DataFrame(data=[[name,company,year,kms_driven,fuel_type]],columns=['name', 'company', 'year',  'kms_driven', 'fuel_type'])

# %%
input
# Out:
#                                name company  year  kms_driven fuel_type
# 0  Suzuki Swift Dzire VXi 1.2 BS IV  Maruti  2017       35000    Petrol

# %%
pipe.predict(input)
# Out:
# array([[437024.70896639]])
